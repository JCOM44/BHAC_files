# %% [markdown]
# # BHAC visual

# %%
import numpy as np
from matplotlib import pyplot as plt  
from scipy import interpolate
import vtk 

import os, sys 

# Link BHAC python tools directory
Bhacdir         = os.environ.get("BHAC_DIR")
Bhac_python_dir = Bhacdir+"/tools/python"
print(f"BHAC_dir found in: {Bhacdir}")

sys.path.append(Bhac_python_dir)
import read, amrplot

# Set data directory for simulation analysis
DIR_test   = "/home/jolivera/BHAC/PS/SimData/"
DIR_PSLowB = "/home/jolivera/BHAC/BHAC_files/ProcaStarLowB/output"
DIR_PSMAD  = "/home/jolivera/BHAC/BHAC_files/ProcaStarMAD/output"
# Out:
# BHAC_dir found in: /home/jolivera/BHAC/bhac

# %%
# read data from vtu 
os.chdir(DIR_test)
# %ls
d=read.load(1000,file="data_d3_x+0.00D+00_n",type='vtu',rotateX=-90)

p1=amrplot.polyplot(d.rho,d,xrange=[0,100],yrange=[-50,50])
# Out:
# data_d2_x+0.16D+01_n1000.vtu  data_d3_x+0.31D+01_n1000.vtu
# data_d3_x+0.00D+00_n1000.vtu  data_d3_x+0.47D+01_n1000.vtu
# data_d3_x+0.16D+01_n1000.vtu
# ...
# loading file data_d3_x+0.00D+00_n1000.vtu
# Reading data time= 0.564913 sec
# ========== Initializing ... ============
# Assigning variable: rho
# Assigning variable: u1
# Assigning variable: u2
# Assigning variable: u3
# Assigning variable: p
# Assigning variable: b1
# Assigning variable: b2
# Assigning variable: b3
# Assigning variable: s
# Assigning variable: tr1
# Assigning variable: lfac
# Assigning variable: xi
# Assigning variable: B2
# Assigning variable: divB
# Assigning variable: gav
# Assigning variable: rhoav
# Assigning variable: tav
# Assigning variable: bav
# Assigning variable: pav
# Assigning variable: pmagav
# Assigning variable: betaav
# Assigning variable: mdot_int
# Assigning variable: phi_int
# Assigning variable: TEMrt
# Assigning variable: TPAKErt
# Assigning variable: TENrt
# Assigning variable: hut
# ...

# %%
d=read.loadvti(0,file="data_d1_l3")
# Out:
# ...
# loading file data_d1_l30000.vti
# Reading data time= 0.000303 sec
# ========== Initializing ... ============
# Getting vars time= 0.000423 sec
# ========== Finished loading 0 cells in 0.000813 sec, have a nice day! ===========
# 2024-10-28 13:57:03.216 (5872.123s) [    7EBF329E9080]       vtkXMLReader.cxx:295    ERR| vtkXMLImageDataReader (0x32acc80): Error opening file data_d1_l30000.vti
# 2024-10-28 13:57:03.216 (5872.123s) [    7EBF329E9080]       vtkExecutive.cxx:729    ERR| vtkCompositeDataPipeline (0x3272140): Algorithm vtkXMLImageDataReader (0x32acc80) returned failure for request: vtkInformation (0x31d9410)
#   Debug: Off
#   Modified Time: 245
#   Reference Count: 1
#   Registered Events: (none)
#   Request: REQUEST_INFORMATION
#   ALGORITHM_AFTER_FORWARD: 1
#   FORWARD_DIRECTION: 0

# %%
# read data from vtu 
os.chdir(DIR_PSLowB)

d=read.load(2,file="data_d3_x+0.00D+00_n",type='vtu',rotateX=-90)

p1=amrplot.polyplot(d.rho,d,xrange=[0,50],yrange=[-20,20],fig_h=40,fig_w=10)
# Out:
# ...
# loading file data_d3_x+0.00D+00_n0002.vtu
# Reading data time= 0.516097 sec
# ========== Initializing ... ============
# Assigning variable: rho
# Assigning variable: u1
# Assigning variable: u2
# Assigning variable: u3
# Assigning variable: p
# Assigning variable: b1
# Assigning variable: b2
# Assigning variable: b3
# Assigning variable: s
# Assigning variable: tr1
# Assigning variable: lfac
# Assigning variable: xi
# Assigning variable: B2
# Assigning variable: divB
# Assigning variable: gav
# Assigning variable: rhoav
# Assigning variable: tav
# Assigning variable: bav
# Assigning variable: pav
# Assigning variable: pmagav
# Assigning variable: betaav
# Assigning variable: mdot_int
# Assigning variable: phi_int
# Assigning variable: TEMrt
# Assigning variable: TPAKErt
# Assigning variable: TENrt
# Assigning variable: hut
# Assigning variable: ldot_int
# Assigning variable: mype
# Assigning variable: Q_r
# Assigning variable: Q_theta
# Assigning variable: Q_phi
# ...
